# %%
# ================================================
# 1. Imports
# ================================================
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# ================================================
# 2. Load datasets (train + eval)
# ================================================
train_df = pd.read_csv(r"C:\Users\GUESTT\Desktop\Regression_ML_EndtoEnd\data\processed\feature_engineered_train.csv")
eval_df  = pd.read_csv(r"C:\Users\GUESTT\Desktop\Regression_ML_EndtoEnd\data\processed\feature_engineered_eval.csv")

# %%
'''
# ================================================
# 3. Drop high VIF features (both train + eval)
# ================================================
high_vif_features = [
    "median_sale_price" #highest correlation to 'price' => data leakage
]
train_df.drop(columns=high_vif_features, inplace=True)
eval_df.drop(columns=high_vif_features, inplace=True)
'''
# Out:
# '\n# ================================================\n# 3. Drop high VIF features (both train + eval)\n# ================================================\nhigh_vif_features = [\n    "median_sale_price" #highest correlation to \'price\' => data leakage\n]\ntrain_df.drop(columns=high_vif_features, inplace=True)\neval_df.drop(columns=high_vif_features, inplace=True)\n'

# %%
# ================================================
# 4. Define target & features
# ================================================
target = "price"
X_train = train_df.drop(columns=[target])
y_train = train_df[target]

X_eval = eval_df.drop(columns=[target])
y_eval = eval_df[target]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576815 entries, 0 to 576814
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   year                          576815 non-null  int64
#  1   quarter                       576815 non-null  int64
#  2   month                         576815 non-null  int64
#  3   median_list_price             576815 non-null  float64
#  4   median_ppsf                   576815 non-null  float64
#  5   median_list_ppsf              576815 non-null  float64
#  6   homes_sold                    576815 non-null  float64
#  7   pending_sales                 576815 non-null  float64
#  8   new_listings                  576815 non-null  float64
#  9   inventory                     576815 non-null  float64
#  10  median_dom                    576815 non-null  float64
#  11  avg_sale_to_list              576815 non-null  float64
#  12  sold_above_list               576815 non-null  float64
#  13  off_market_in_two_weeks       576815 non-null  float64
#  14  bank                          576815 non-null  float64
#  15  bus                           576815 non-null  float64
#  16  hospital                      576815 non-null  float64
#  17  mall                          576815 non-null  float64
#  18  park                          576815 non-null  float64
#  19  restaurant                    576815 non-null  float64
#  20  school                        576815 non-null  float64
#  21  station                       576815 non-null  float64
#  22  supermarket                   576815 non-null  float64
#  23  Total Population              576815 non-null  float64
#  24  Median Age                    576815 non-null  float64
#  25  Per Capita Income             576815 non-null  float64
#  26  Total Families Below Poverty  576815 non-null  float64
#  27  Total Housing Units           576815 non-null  float64
#  28  Median Rent                   576815 non-null  float64
#  29  Median Home Value             576815 non-null  float64
#  30  Total Labor Force             576815 non-null  float64
#  31  Unemployed Population         576815 non-null  float64
#  32  Total School Age Population   576815 non-null  float64
#  33  Total School Enrollment       576815 non-null  float64
#  34  Median Commute Time           576815 non-null  float64
#  35  lat                           0 non-null       float64
#  36  lng                           0 non-null       float64
#  37  zipcode_freq                  576815 non-null  int64
#  38  city_encoded                  576815 non-null  float64
# dtypes: float64(35), int64(4)
# memory usage: 171.6 MB

# %%
null_cols = train_df.columns[train_df.isnull().all()]

print(null_cols)

train_df = train_df.drop(columns=null_cols)
eval_df = eval_df.drop(columns=null_cols)
# Out:
# Index(['lat', 'lng'], dtype='object')

# %%
target = "price"

X_train = train_df.drop(columns=[target])
y_train = train_df[target]

X_eval = eval_df.drop(columns=[target])
y_eval = eval_df[target]

# %%
# ================================================
# 5. Standardization (fit on train, transform eval)
# ================================================
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_eval_scaled  = scaler.transform(X_eval)

# %%
# ================================================
# 6. Train & Evaluate Models
# ================================================

# --- Linear Regression ---
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
y_pred_lr = lr.predict(X_eval_scaled)

print("Linear Regression:")
print(" MAE:", mean_absolute_error(y_eval, y_pred_lr))
print(" RMSE:", np.sqrt(mean_squared_error(y_eval, y_pred_lr)))
print(" R²:", r2_score(y_eval, y_pred_lr))
# Out:
# Linear Regression:
#  MAE: 53811.93813400813
#  RMSE: 121336.1346929599
#  R²: 0.8862267031700115

# %%
# --- Ridge Regression ---
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, y_train)
y_pred_ridge = ridge.predict(X_eval_scaled)

print("\nRidge Regression:")
print(" MAE:", mean_absolute_error(y_eval, y_pred_ridge))
print(" RMSE:", np.sqrt(mean_squared_error(y_eval, y_pred_ridge)))
print(" R²:", r2_score(y_eval, y_pred_ridge))
# Out:
# Ridge Regression:
#  MAE: 53811.11466044342
#  RMSE: 121338.02551498078
#  R²: 0.8862231572068611

# %%
# --- Lasso Regression ---
lasso = Lasso(alpha=0.1)
lasso.fit(X_train_scaled, y_train)
y_pred_lasso = lasso.predict(X_eval_scaled)

print("\nLasso Regression:")
print(" MAE:", mean_absolute_error(y_eval, y_pred_lasso))
print(" RMSE:", np.sqrt(mean_squared_error(y_eval, y_pred_lasso)))
print(" R²:", r2_score(y_eval, y_pred_lasso))
# Out:
# c:\Users\GUESTT\Desktop\Regression_ML_EndtoEnd\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.114e+15, tolerance: 5.209e+12
#   model = cd_fast.enet_coordinate_descent(
# Lasso Regression:
#  MAE: 54117.4260712303
#  RMSE: 121604.4782343721
#  R²: 0.8857229111303108

# %%
# --- ElasticNet ---
elastic = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic.fit(X_train_scaled, y_train)
y_pred_elastic = elastic.predict(X_eval_scaled)

print("\nElasticNet Regression:")
print(" MAE:", mean_absolute_error(y_eval, y_pred_elastic))
print(" RMSE:", np.sqrt(mean_squared_error(y_eval, y_pred_elastic)))
print(" R²:", r2_score(y_eval, y_pred_elastic))
# Out:
# ElasticNet Regression:
#  MAE: 54234.24932061461
#  RMSE: 122295.84870428537
#  R²: 0.8844197946433394
